# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
from datetime import datetime, timedelta
import robin_stocks.robinhood as r

# %%
#Pull user name in form .env
# import * from credentials.env
import os
from dotenv import load_dotenv
import pyotp

load_dotenv()

code = os.getenv('MFA')

MFA = pyotp.TOTP(code).now()
username = os.getenv('USERNAME')
password = os.getenv('PASSWORD')

# %%
login = r.login(username, password, mfa_code=MFA)

# %%
login
# Out:
# {'access_token': 'eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiJ9.....dchu2sBpJi04-uep5xeIrczHUuAsBNw93JEwwIogjtPfuPQeGVDtCzUekXoO4orBfXJqZyeICFZrKunnGsJK1GmcmoY0zH8CdJFLq1fieeMOAKOPeTyMtiiqIAqEBtE8YnG-Gn-EPU5nH7MBwdiO63r5AwUFDom3xl99hwND0aynn1cYlcRHRHEQRguNO4a6X-K10-FIFLGVf3pYdMT6H4D1vY8jOv9_nXAQwVeuXE3vuQANGV9kvYkhZMz_HsTCQpF8h6ccN1gyJv4vSbWkA1v0wtJuR5jZMLPWzaqZ8J7Gl4KWtCcLvv9I_focpOBF_NKUHu90wUCp99LmkByBnQ',
#  'token_type': 'Bearer',
#  'expires_in': 86400,
#  'scope': 'internal',
#  'detail': 'logged in using authentication in robinhood.pickle',
#  'backup_code': None,
#  'refresh_token': 'M9RxvqYNRrI7vx1TKswaL9yv2NgExx'}

# %%
#Quesry your positions
positions = r.get_open_stock_positions()

# %%
positions
# Out:
# [{'url': 'https://api.robinhood.com/positions/730028552/d8edff21-cb19-4373-af1c-f83a3c0d01c4/',
#   'instrument': 'https://api.robinhood.com/instruments/d8edff21-cb19-4373-af1c-f83a3c0d01c4/',
#   'instrument_id': 'd8edff21-cb19-4373-af1c-f83a3c0d01c4',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '7.3770',
#   'pending_average_buy_price': '7.3770',
#   'quantity': '6.62467500',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '6.62467500',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-09-20T13:39:38.549213Z',
#   'created_at': '2020-03-16T20:51:45.497494Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/38dc15e8-071c-4544-88b3-f633f0a69a4f/',
#   'instrument': 'https://api.robinhood.com/instruments/38dc15e8-071c-4544-88b3-f633f0a69a4f/',
#   'instrument_id': '38dc15e8-071c-4544-88b3-f633f0a69a4f',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '5.4590',
#   'pending_average_buy_price': '5.4590',
#   'quantity': '4.00758400',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '4.00758400',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-06-24T13:33:40.175250Z',
#   'created_at': '2020-03-17T06:54:22.957139Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/9133b38b-4917-4b5a-8eab-c029d60f9912/',
#   'instrument': 'https://api.robinhood.com/instruments/9133b38b-4917-4b5a-8eab-c029d60f9912/',
#   'instrument_id': '9133b38b-4917-4b5a-8eab-c029d60f9912',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '36.0989',
#   'pending_average_buy_price': '36.0989',
#   'quantity': '3.17489800',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '3.17489800',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-06-11T13:34:39.587997Z',
#   'created_at': '2020-03-13T04:10:06.638690Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/bb9a01df-5982-42d4-88db-8662f23cdab5/',
#   'instrument': 'https://api.robinhood.com/instruments/bb9a01df-5982-42d4-88db-8662f23cdab5/',
#   'instrument_id': 'bb9a01df-5982-42d4-88db-8662f23cdab5',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '43.6349',
#   'pending_average_buy_price': '43.6349',
#   'quantity': '3.07202500',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '3.07202500',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-07-02T13:37:55.713002Z',
#   'created_at': '2020-03-17T16:32:28.475856Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/4e0f05f4-4c50-4dad-a69b-41729ec1a6a9/',
#   'instrument': 'https://api.robinhood.com/instruments/4e0f05f4-4c50-4dad-a69b-41729ec1a6a9/',
#   'instrument_id': '4e0f05f4-4c50-4dad-a69b-41729ec1a6a9',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '20.3040',
#   'pending_average_buy_price': '20.3040',
#   'quantity': '7.45717600',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '7.45717600',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-08-17T13:33:57.436645Z',
#   'created_at': '2020-03-18T14:02:34.914010Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/9b2ff74c-6f46-415d-a226-0c72488c8a0d/',
#   'instrument': 'https://api.robinhood.com/instruments/9b2ff74c-6f46-415d-a226-0c72488c8a0d/',
#   'instrument_id': '9b2ff74c-6f46-415d-a226-0c72488c8a0d',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '47.2377',
#   'pending_average_buy_price': '47.2377',
#   'quantity': '2.07164700',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '2.07164700',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-08-20T13:31:10.291953Z',
#   'created_at': '2020-03-24T16:24:22.964112Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/155305e2-65cd-474a-a25f-a7f0b44c19fc/',
#   'instrument': 'https://api.robinhood.com/instruments/155305e2-65cd-474a-a25f-a7f0b44c19fc/',
#   'instrument_id': '155305e2-65cd-474a-a25f-a7f0b44c19fc',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '27.9338',
#   'pending_average_buy_price': '27.9338',
#   'quantity': '3.09839900',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '3.09839900',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-08-02T17:01:56.440418Z',
#   'created_at': '2020-03-24T18:59:24.734039Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/99ddbcfc-589a-4947-a346-08c23d20806f/',
#   'instrument': 'https://api.robinhood.com/instruments/99ddbcfc-589a-4947-a346-08c23d20806f/',
#   'instrument_id': '99ddbcfc-589a-4947-a346-08c23d20806f',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '10.1323',
#   'pending_average_buy_price': '10.1323',
#   'quantity': '6.52172200',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '6.52172200',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-08-16T13:33:13.457323Z',
#   'created_at': '2020-04-26T16:38:06.017251Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/5448380e-fb98-499a-adbe-5c7e02563597/',
#   'instrument': 'https://api.robinhood.com/instruments/5448380e-fb98-499a-adbe-5c7e02563597/',
#   'instrument_id': '5448380e-fb98-499a-adbe-5c7e02563597',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '17.3330',
#   'pending_average_buy_price': '17.3330',
#   'quantity': '2.00888100',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '2.00888100',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-06-24T13:32:27.026801Z',
#   'created_at': '2020-05-06T13:31:23.918690Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/abecb592-bd1f-444e-9474-9abd88eb753b/',
#   'instrument': 'https://api.robinhood.com/instruments/abecb592-bd1f-444e-9474-9abd88eb753b/',
#   'instrument_id': 'abecb592-bd1f-444e-9474-9abd88eb753b',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '3.9978',
#   'pending_average_buy_price': '3.9978',
#   'quantity': '39.95210600',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '39.95210600',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-10-29T20:37:19.544464Z',
#   'created_at': '2020-03-17T07:22:02.333020Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/27e539a7-48ea-475d-858c-9cf5f6eb5e65/',
#   'instrument': 'https://api.robinhood.com/instruments/27e539a7-48ea-475d-858c-9cf5f6eb5e65/',
#   'instrument_id': '27e539a7-48ea-475d-858c-9cf5f6eb5e65',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '30.8467',
#   'pending_average_buy_price': '30.8467',
#   'quantity': '4.23287200',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '4.23287200',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-08-16T13:34:41.985988Z',
#   'created_at': '2020-06-01T15:47:31.899858Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/b9a6444e-ce3e-4186-be32-b82814d2b418/',
#   'instrument': 'https://api.robinhood.com/instruments/b9a6444e-ce3e-4186-be32-b82814d2b418/',
#   'instrument_id': 'b9a6444e-ce3e-4186-be32-b82814d2b418',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '29.6900',
#   'pending_average_buy_price': '29.6900',
#   'quantity': '5.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '5.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2020-10-28T19:44:46.227103Z',
#   'created_at': '2020-10-28T19:44:45.339283Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/48e003a5-558e-4975-b4a3-2c36bbd5e423/',
#   'instrument': 'https://api.robinhood.com/instruments/48e003a5-558e-4975-b4a3-2c36bbd5e423/',
#   'instrument_id': '48e003a5-558e-4975-b4a3-2c36bbd5e423',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '9.8491',
#   'pending_average_buy_price': '9.8491',
#   'quantity': '20.92371600',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '20.92371600',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-08-13T13:32:11.604162Z',
#   'created_at': '2020-11-02T14:39:01.815702Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/44becb6f-9f16-4db5-8a36-3efebc21b069/',
#   'instrument': 'https://api.robinhood.com/instruments/44becb6f-9f16-4db5-8a36-3efebc21b069/',
#   'instrument_id': '44becb6f-9f16-4db5-8a36-3efebc21b069',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '6.5180',
#   'pending_average_buy_price': '6.5180',
#   'quantity': '5.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '5.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2020-06-24T19:12:49.742524Z',
#   'created_at': '2020-06-18T18:42:26.574585Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/330579a8-907e-49d2-97a7-92a8d1a20088/',
#   'instrument': 'https://api.robinhood.com/instruments/330579a8-907e-49d2-97a7-92a8d1a20088/',
#   'instrument_id': '330579a8-907e-49d2-97a7-92a8d1a20088',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '3.5669',
#   'pending_average_buy_price': '3.5669',
#   'quantity': '174.30406400',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '174.30406400',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-07-28T13:36:51.178734Z',
#   'created_at': '2021-01-17T19:18:27.300756Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/91da75e3-1684-4ed8-b976-1be0121aa16d/',
#   'instrument': 'https://api.robinhood.com/instruments/91da75e3-1684-4ed8-b976-1be0121aa16d/',
#   'instrument_id': '91da75e3-1684-4ed8-b976-1be0121aa16d',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '9.4594',
#   'pending_average_buy_price': '9.4594',
#   'quantity': '25.97633200',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '25.97633200',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-08-02T16:58:16.977409Z',
#   'created_at': '2021-01-17T19:26:24.819783Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/3324b13c-dc23-40e8-8807-76d87fdb09ed/',
#   'instrument': 'https://api.robinhood.com/instruments/3324b13c-dc23-40e8-8807-76d87fdb09ed/',
#   'instrument_id': '3324b13c-dc23-40e8-8807-76d87fdb09ed',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '21.0067',
#   'pending_average_buy_price': '21.0067',
#   'quantity': '3.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '3.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-02-10T19:08:47.087866Z',
#   'created_at': '2020-08-15T22:25:48.234030Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/e845f67a-ecb8-4704-9aca-c5699b68a29d/',
#   'instrument': 'https://api.robinhood.com/instruments/e845f67a-ecb8-4704-9aca-c5699b68a29d/',
#   'instrument_id': 'e845f67a-ecb8-4704-9aca-c5699b68a29d',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '11.8512',
#   'pending_average_buy_price': '11.8512',
#   'quantity': '44.99805600',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '44.99805600',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-07-16T13:34:05.841988Z',
#   'created_at': '2021-01-25T14:06:46.573872Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/7a6a30e2-cf4d-40dd-8baa-0cea48de85e4/',
#   'instrument': 'https://api.robinhood.com/instruments/7a6a30e2-cf4d-40dd-8baa-0cea48de85e4/',
#   'instrument_id': '7a6a30e2-cf4d-40dd-8baa-0cea48de85e4',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '89.6738',
#   'pending_average_buy_price': '89.6738',
#   'quantity': '3.03700600',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '3.03700600',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-06-11T13:33:46.696671Z',
#   'created_at': '2021-01-25T14:39:53.264566Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/68a7e911-e3a0-4a4a-8d24-19bf06d78fb4/',
#   'instrument': 'https://api.robinhood.com/instruments/68a7e911-e3a0-4a4a-8d24-19bf06d78fb4/',
#   'instrument_id': '68a7e911-e3a0-4a4a-8d24-19bf06d78fb4',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '43.8351',
#   'pending_average_buy_price': '43.8351',
#   'quantity': '5.04276100',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '5.04276100',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-07-16T13:34:06.332142Z',
#   'created_at': '2021-01-25T14:41:32.330938Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/4a0fb027-1e8a-4337-979e-f2fc7abb3100/',
#   'instrument': 'https://api.robinhood.com/instruments/4a0fb027-1e8a-4337-979e-f2fc7abb3100/',
#   'instrument_id': '4a0fb027-1e8a-4337-979e-f2fc7abb3100',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '10.8219',
#   'pending_average_buy_price': '10.8219',
#   'quantity': '36.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '36.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-07-23T09:03:29.740157Z',
#   'created_at': '2021-07-23T09:03:28.198623Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/94a817dc-1cdb-42e6-a803-8de1bb2505d4/',
#   'instrument': 'https://api.robinhood.com/instruments/94a817dc-1cdb-42e6-a803-8de1bb2505d4/',
#   'instrument_id': '94a817dc-1cdb-42e6-a803-8de1bb2505d4',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '214.7300',
#   'pending_average_buy_price': '214.7300',
#   'quantity': '1.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '1.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-10-29T13:30:12.537748Z',
#   'created_at': '2021-10-29T00:45:24.292940Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/f2456068-8002-4486-b06b-101c03cfff1c/',
#   'instrument': 'https://api.robinhood.com/instruments/f2456068-8002-4486-b06b-101c03cfff1c/',
#   'instrument_id': 'f2456068-8002-4486-b06b-101c03cfff1c',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '122.6300',
#   'pending_average_buy_price': '122.6300',
#   'quantity': '1.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '1.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-10-29T13:30:20.850964Z',
#   'created_at': '2021-10-29T00:45:43.575279Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/18006bfb-cbad-4326-8348-738c94ea47fa/',
#   'instrument': 'https://api.robinhood.com/instruments/18006bfb-cbad-4326-8348-738c94ea47fa/',
#   'instrument_id': '18006bfb-cbad-4326-8348-738c94ea47fa',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '134.7900',
#   'pending_average_buy_price': '134.7900',
#   'quantity': '1.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '1.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-10-29T13:30:16.747127Z',
#   'created_at': '2021-10-29T00:45:54.610243Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/50810c35-d215-4866-9758-0ada4ac79ffa/',
#   'instrument': 'https://api.robinhood.com/instruments/50810c35-d215-4866-9758-0ada4ac79ffa/',
#   'instrument_id': '50810c35-d215-4866-9758-0ada4ac79ffa',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '323.8898',
#   'pending_average_buy_price': '323.8898',
#   'quantity': '0.30874700',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '0.30874700',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-10-29T13:30:19.767247Z',
#   'created_at': '2021-10-29T00:46:12.957043Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/da2feba1-49bd-4190-83f9-f0b643990267/',
#   'instrument': 'https://api.robinhood.com/instruments/da2feba1-49bd-4190-83f9-f0b643990267/',
#   'instrument_id': 'da2feba1-49bd-4190-83f9-f0b643990267',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '18.0055',
#   'pending_average_buy_price': '18.0055',
#   'quantity': '4.52803300',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '4.52803300',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-11-26T14:30:01.603977Z',
#   'created_at': '2020-10-30T22:43:10.750763Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/8e1f15ad-12b2-49a4-b5b1-acf4e39a70b8/',
#   'instrument': 'https://api.robinhood.com/instruments/8e1f15ad-12b2-49a4-b5b1-acf4e39a70b8/',
#   'instrument_id': '8e1f15ad-12b2-49a4-b5b1-acf4e39a70b8',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '20.5510',
#   'pending_average_buy_price': '20.5510',
#   'quantity': '2.43297700',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '2.43297700',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-11-26T14:30:07.229292Z',
#   'created_at': '2021-11-26T02:20:47.931432Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/257e4dc9-f4b0-4e57-b6ab-afda86dac3e3/',
#   'instrument': 'https://api.robinhood.com/instruments/257e4dc9-f4b0-4e57-b6ab-afda86dac3e3/',
#   'instrument_id': '257e4dc9-f4b0-4e57-b6ab-afda86dac3e3',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '14.6500',
#   'pending_average_buy_price': '14.6500',
#   'quantity': '3.41296900',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '3.41296900',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-11-26T14:30:03.180840Z',
#   'created_at': '2021-11-26T02:22:30.401902Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/1bd0c248-ad06-413d-99ae-9baaaa3acd06/',
#   'instrument': 'https://api.robinhood.com/instruments/1bd0c248-ad06-413d-99ae-9baaaa3acd06/',
#   'instrument_id': '1bd0c248-ad06-413d-99ae-9baaaa3acd06',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '12.4400',
#   'pending_average_buy_price': '12.4400',
#   'quantity': '4.01929200',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '4.01929200',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-11-26T14:30:02.488978Z',
#   'created_at': '2021-11-26T02:22:54.746921Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/18226051-6bfa-4c56-bd9a-d7575f0245c1/',
#   'instrument': 'https://api.robinhood.com/instruments/18226051-6bfa-4c56-bd9a-d7575f0245c1/',
#   'instrument_id': '18226051-6bfa-4c56-bd9a-d7575f0245c1',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '242.7000',
#   'pending_average_buy_price': '242.7000',
#   'quantity': '10.00000000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '10.00000000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2021-12-29T13:58:09.655068Z',
#   'created_at': '2021-12-28T03:01:00.019108Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/ebab2398-028d-4939-9f1d-13bf38f81c50/',
#   'instrument': 'https://api.robinhood.com/instruments/ebab2398-028d-4939-9f1d-13bf38f81c50/',
#   'instrument_id': 'ebab2398-028d-4939-9f1d-13bf38f81c50',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '225.7383',
#   'pending_average_buy_price': '225.7383',
#   'quantity': '2.63748000',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '2.63748000',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2022-02-09T14:55:54.630244Z',
#   'created_at': '2022-02-09T14:46:20.793517Z'},
#  {'url': 'https://api.robinhood.com/positions/730028552/8decc068-5bfd-4cc6-bb2c-f2efd3119536/',
#   'instrument': 'https://api.robinhood.com/instruments/8decc068-5bfd-4cc6-bb2c-f2efd3119536/',
#   'instrument_id': '8decc068-5bfd-4cc6-bb2c-f2efd3119536',
#   'account': 'https://api.robinhood.com/accounts/730028552/',
#   'account_number': '730028552',
#   'average_buy_price': '182.0000',
#   'pending_average_buy_price': '182.0000',
#   'quantity': '2.74725200',
#   'intraday_average_buy_price': '0.0000',
#   'intraday_quantity': '0.00000000',
#   'shares_available_for_exercise': '2.74725200',
#   'shares_held_for_buys': '0.00000000',
#   'shares_held_for_sells': '0.00000000',
#   'shares_held_for_stock_grants': '0.00000000',
#   'shares_held_for_options_collateral': '0.00000000',
#   'shares_held_for_options_events': '0.00000000',
#   'shares_pending_from_options_events': '0.00000000',
#   'shares_available_for_closing_short_position': '0.00000000',
#   'ipo_allocated_quantity': '0.00000000',
#   'ipo_dsp_allocated_quantity': '0.00000000',
#   'avg_cost_affected': False,
#   'avg_cost_affected_reason': None,
#   'is_primary_account': True,
#   'updated_at': '2022-02-09T14:57:11.113542Z',
#   'created_at': '2022-02-09T14:57:09.287886Z'}]

# %%
# Get Ticker symbols
tickers = [r.get_symbol_by_url(item["instrument"]) for item in positions]

# Get your quantities
quantities = [float(item["quantity"]) for item in positions]

# Query previous close price for each stock ticker
prevClose = r.get_quotes(tickers, "previous_close")

# Query last trading price for each stock ticker
lastPrice = r.get_quotes(tickers, "last_trade_price")

# Calculate the profit per share
profitPerShare = [float(lastPrice[i]) - float(prevClose[i]) for i in range(len(tickers))]

# Calculate the percent change for each stock ticker
percentChange = [ 100.0 * profitPerShare[i] / float(prevClose[i]) for i in range(len(tickers)) ]

# Calcualte your profit for each stock ticker
profit = [profitPerShare[i] * quantities[i] for i in range(len(tickers))]

# Combine into list of lists, for sorting
tickersPerf = list(zip(profit, percentChange, tickers))

tickersPerf.sort(reverse=True)

print ("My Positions Performance:")
print ("Ticker | DailyGain | PercentChange")
for item in tickersPerf:
  print ("%s %f$ %f%%" % (item[2], item[0], item[1]))

print ("Net Gain:", sum(profit))
# Out:
# My Positions Performance:
# Ticker | DailyGain | PercentChange
# VTI 48.200000$ 2.225403%
# OKE 18.419225$ 4.014302%
# CVX 16.794643$ 4.100853%
# ARI 10.799533$ 1.879405%
# FB 7.595942$ 1.387283%
# KO 7.188539$ 3.867129%
# NDAQ 6.950548$ 1.486574%
# XOM 6.476792$ 2.691293%
# DAL 6.050000$ 3.000248%
# LEG 5.950458$ 3.265984%
# NRZ 5.455030$ 2.044791%
# WELL 4.744072$ 2.792002%
# SPHD 4.368743$ 3.214041%
# HAL 4.248039$ 3.368287%
# CEQP 3.847816$ 2.026795%
# OHI 3.089997$ 2.632528%
# SRET 2.929320$ 1.607348%
# PAYX 2.850000$ 2.461352%
# DIV 2.626259$ 2.923387%
# TROW 2.520000$ 1.765448%
# KSS 2.430746$ 2.173523%
# AMAT 2.300000$ 1.723879%
# CCL 1.410000$ 2.278236%
# MUR 1.391182$ 0.637329%
# MSFT 0.839792$ 0.923317%
# KBWD 0.802882$ 1.760000%
# NYMT 0.799042$ 0.573066%
# PGX 0.614334$ 1.337296%
# SDIV 0.522508$ 1.122625%
# CLDT -0.950000$ -1.358113%
# IVR -3.486081$ -0.904977%
# MITT -9.360000$ -2.829162%
# Net Gain: 168.4193598299999

# %%
infomation =  r.get_quotes(tickers)

# %%
infomation[0]
# Out:
# {'ask_price': '40.000000',
#  'ask_size': 400,
#  'bid_price': '32.900000',
#  'bid_size': 50,
#  'last_trade_price': '33.160000',
#  'last_extended_hours_trade_price': '33.160000',
#  'previous_close': '32.950000',
#  'adjusted_previous_close': '32.950000',
#  'previous_close_date': '2022-02-24',
#  'symbol': 'MUR',
#  'trading_halted': False,
#  'has_traded': True,
#  'last_trade_price_source': 'consolidated',
#  'updated_at': '2022-02-26T01:00:00Z',
#  'instrument': 'https://api.robinhood.com/instruments/d8edff21-cb19-4373-af1c-f83a3c0d01c4/',
#  'instrument_id': 'd8edff21-cb19-4373-af1c-f83a3c0d01c4',
#  'state': 'active'}

# %%
 test = r.load_portfolio_profile()

# %%
test['equity']
# Out:
# '8835.7228'

# %%
 test2 = r.load_security_profile()
